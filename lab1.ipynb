# %% [markdown]
# ## Business Data Analytics Lab 1

# %% [markdown]
# ### Importing pandas and numpy

# %%
import numpy as np

import pandas as pd

# %%
data = pd.read_csv("retail_sales.csv")

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Invoice ID      11 non-null     object
#  1   Date            10 non-null     object
#  2   Customer Name   10 non-null     object
#  3   Product         10 non-null     object
#  4   Category        11 non-null     object
#  5   Quantity        10 non-null     float64
#  6   Unit Price      10 non-null     float64
#  7   Total           8 non-null      float64
#  8   Payment Method  11 non-null     object
#  9   Store           11 non-null     object
# dtypes: float64(3), object(7)
# memory usage: 1012.0+ bytes

# %%
data.head()
# Out:
#   Invoice ID        Date Customer Name     Product     Category  Quantity  \
# 0     INV001  2025-01-05      John Doe      Laptop  Electronics       1.0
# 1     INV002  05/01/2025    jane smith  Smartphone  Electronics       2.0
# 2     INV003  2025/01/06   Ali Hussein         NaN  Electronics       1.0
# 3     INV004  2025-01-07  Mary Wangari  Headphones  Electronics       NaN
# 4     INV005  2025-01-07      JOHN DOE      Laptop  Electronics       1.0
#
#    Unit Price   Total Payment Method    Store
# 0      899.99  899.99    Credit Card  Nairobi
# 1      499.50  999.00    credit card  Nairobi
# 2      599.99     NaN           Cash  Mombasa
# 3       99.99     NaN           Cash  Mombasa
# 4      899.99  899.99    Credit Card  Nairobi

# %%
data = data.drop_duplicates()
data
# Out:
#    Invoice ID        Date  Customer Name         Product     Category  \
# 0      INV001  2025-01-05       John Doe          Laptop  Electronics
# 1      INV002  05/01/2025     jane smith      Smartphone  Electronics
# 2      INV003  2025/01/06    Ali Hussein             NaN  Electronics
# 3      INV004  2025-01-07   Mary Wangari      Headphones  Electronics
# 4      INV005  2025-01-07       JOHN DOE          Laptop  Electronics
# 5      INV006         NaN    Anne Mwangi         Blender         Home
# 6      INV007  2025-01-08   Peter Otieno       Microwave         Home
# 7      INV008  2025-01-09     Jane Smith          Laptop  Electronics
# 9      INV009  2025-01-10            NaN              TV  Electronics
# 10     INV010  10-01-2025  James Kariuki  Vacuum Cleaner         Home
#
#     Quantity  Unit Price    Total Payment Method    Store
# 0        1.0      899.99   899.99    Credit Card  Nairobi
# 1        2.0      499.50   999.00    credit card  Nairobi
# ...

# %%
# we can use either 
# data['Total'].fillna(data['Total'].mean(),inplace=True)

# or the following
# data.fillna({'Total': data['Total'].mean()},inplace=True)

# data.fillna({'Total': data['Total'].mean()},inplace=True)
# data
data['Product'].dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       1 # we can use either
#       2 # data['Total'].fillna(data['Total'].mean(),inplace=True)
#       3
#    (...)
#       7 # data.fillna({'Total': data['Total'].mean()},inplace=True)
#       8 # data
# ----> 9 data['Product'].dropna()
#
# NameError: name 'data' is not defined

# %%
data
# Out:
#    Invoice ID        Date  Customer Name         Product     Category  \
# 0      INV001  2025-01-05       John Doe          Laptop  Electronics
# 1      INV002  05/01/2025     jane smith      Smartphone  Electronics
# 2      INV003  2025/01/06    Ali Hussein             NaN  Electronics
# 3      INV004  2025-01-07   Mary Wangari      Headphones  Electronics
# 4      INV005  2025-01-07       JOHN DOE          Laptop  Electronics
# 5      INV006         NaN    Anne Mwangi         Blender         Home
# 6      INV007  2025-01-08   Peter Otieno       Microwave         Home
# 7      INV008  2025-01-09     Jane Smith          Laptop  Electronics
# 9      INV009  2025-01-10            NaN              TV  Electronics
# 10     INV010  10-01-2025  James Kariuki  Vacuum Cleaner         Home
#
#     Quantity  Unit Price        Total Payment Method    Store
# 0        1.0      899.99   899.990000    Credit Card  Nairobi
# 1        2.0      499.50   999.000000    credit card  Nairobi
# ...
