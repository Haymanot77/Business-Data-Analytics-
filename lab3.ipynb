# %% [markdown]
# # Week 6 Data visualization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the data

# %%
df = pd.read_csv("sales_data.csv")
df
# Out:
#            Date Region     Product  Sales_Amount  Units_Sold     Sales_Person
# 0    2024-08-30  North      Laptop       4922.76          42      Noah Rhodes
# 1    2025-05-03  North     Printer        666.66          22  Angie Henderson
# 2    2024-07-10   East      Laptop       4507.57           1     Allison Hill
# 3    2024-10-26  South      Laptop       1031.39          27  Abigail Shaffer
# 4    2024-09-16  South      Tablet        317.49          32       Gina Moore
# ..          ...    ...         ...           ...         ...              ...
# 195  2025-02-16   West     Monitor       2873.07           6    Daniel Wagner
# 196  2025-02-08  South  Smartphone        301.24          11       Gina Moore
# 197  2024-10-24  North  Smartphone       2710.45          16  Gabrielle Davis
# 198  2024-11-18   West     Monitor       3341.45          12  Angie Henderson
# 199  2025-05-16  North     Printer        437.89          36  Abigail Shaffer
#
# [200 rows x 6 columns]

# %%
df.head()
# Out:
#          Date Region  Product  Sales_Amount  Units_Sold     Sales_Person
# 0  2024-08-30  North   Laptop       4922.76          42      Noah Rhodes
# 1  2025-05-03  North  Printer        666.66          22  Angie Henderson
# 2  2024-07-10   East   Laptop       4507.57           1     Allison Hill
# 3  2024-10-26  South   Laptop       1031.39          27  Abigail Shaffer
# 4  2024-09-16  South   Tablet        317.49          32       Gina Moore

# %%
df.tail()
# Out:
#            Date Region     Product  Sales_Amount  Units_Sold     Sales_Person
# 195  2025-02-16   West     Monitor       2873.07           6    Daniel Wagner
# 196  2025-02-08  South  Smartphone        301.24          11       Gina Moore
# 197  2024-10-24  North  Smartphone       2710.45          16  Gabrielle Davis
# 198  2024-11-18   West     Monitor       3341.45          12  Angie Henderson
# 199  2025-05-16  North     Printer        437.89          36  Abigail Shaffer

# %%
df.describe()
# Out:
#        Sales_Amount  Units_Sold
# count    200.000000  200.000000
# mean    2771.588050   26.345000
# std     1373.074579   13.867861
# min      195.710000    1.000000
# 25%     1623.332500   15.750000
# 50%     2835.010000   27.000000
# 75%     4013.012500   38.000000
# max     4922.760000   50.000000

# %%
sns.barplot(x='Region', y='Sales_Amount', data=df)
plt.title('Sales Amount by Region')
plt.show()

# %%
sns.barplot(x="Product",y="Sales_Amount",data=df)
plt.title("Sales Amount by Product")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df['Date'] = pd.to_datetime(df['Date'])

df['month_num'] = df['Date'].dt.month
monthly_sales = df.groupby(['month_num'])['Sales_Amount'].sum().reset_index()
monthly_sales = monthly_sales.sort_values("month_num")

plt.figure(figsize=(10,0))
sns.lineplot(data=monthly_sales,x='month_num',y='Sales_Amount',markers='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# /home/haymanot/anaconda3/lib/python3.12/site-packages/matplotlib/_tight_bbox.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   fig.patch.set_bounds(x0 / w1, y0 / h1,
# /home/haymanot/anaconda3/lib/python3.12/site-packages/matplotlib/_tight_bbox.py:68: RuntimeWarning: divide by zero encountered in scalar divide
#   fig.bbox.width / w1, fig.bbox.height / h1)
# /home/haymanot/anaconda3/lib/python3.12/site-packages/matplotlib/patches.py:787: RuntimeWarning: invalid value encountered in scalar add
#   y1 = self.convert_yunits(self._y0 + self._height)
# /home/haymanot/anaconda3/lib/python3.12/site-packages/matplotlib/transforms.py:2049: RuntimeWarning: invalid value encountered in scalar add
#   self._mtx[1, 2] += ty

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Example: loading your data
# df = pd.read_csv('your_data.csv')

# Convert 'Date' to datetime if needed
df['Date'] = pd.to_datetime(df['Date'])

# Extract month name or number
df['Month'] = df['Date'].dt.strftime('%b')  # e.g., 'Jan', 'Feb', etc.
# Or use month number for sorting
df['Month_Num'] = df['Date'].dt.month

monthly_sales = df.groupby(['Month_Num', 'Month'])['Sales_Amount'].sum().reset_index()

# Sort by Month_Num to keep months in correct order
monthly_sales = monthly_sales.sort_values('Month_Num')



plt.figure(figsize=(10,6))
sns.lineplot(data=monthly_sales, x='Month', y='Sales_Amount', marker='o')
plt.title('Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Sales Amount')
plt.grid(True)
plt.show()
