# %% [markdown]
# ## Week 4 - Explorstory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Getting data(generating) Sales data from ten retaili branches

# %%
data ={
    "Branch" : ['A','B','C','D','E','F','G','H','I','J'],
    'Monthly Sales (Kshs)' : [550000, 720000, 480000, 660000, 610000, 580000, 690000, 730000, 510000, 620000],
    'Ad Budget (Kshs)' : [50000, 80000, 40000, 70000, 65000, 50000, 72000, 75000, 45000, 68000],
    'Customer Rating' : [4.2, 4.5, 3.8, 4.0, 4.1, 3.9, 4.3, 4.6, 3.7, 4.0]
}

# %% [markdown]
# ## Creating a DataFrame out of the data

# %%
df = pd.DataFrame(data)
df
df.describe()
# Out:
#        Monthly Sales (Kshs)  Ad Budget (Kshs)  Customer Rating
# count             10.000000         10.000000        10.000000
# mean          615000.000000      61500.000000         4.110000
# std            86055.537623      13986.104215         0.292309
# min           480000.000000      40000.000000         3.700000
# 25%           557500.000000      50000.000000         3.925000
# 50%           615000.000000      66500.000000         4.050000
# 75%           682500.000000      71500.000000         4.275000
# max           730000.000000      80000.000000         4.600000

# %% [markdown]
# ## Exercise 1 : Generate summary statistics (mean, median, standard deviation) in Python.

# %%
plt.figure(figsize=(14, 5))
plt.subplot(1,2,1)
sns.histplot(df['Monthly Sales (Kshs)'], bins=5, kde=True, color='skyblue')
plt.title('Histogram of Monthly Sales (Kshs)')
plt.xlabel('Monthly Sales (Kshs)')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(df['Customer Rating'], bins=5, kde=True, color='salmon')
plt.title('Histogram of Customer Ratings')
plt.xlabel('Customer Rating')
plt.ylabel('Frequency')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Exercise 3: Create scatter plot between Ad Budget and Monthly Sales

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Ad Budget (Kshs)', y='Monthly Sales (Kshs)', hue='Branch', palette='tab10', s=100)
plt.title('Ad Budget vs Monthly Sales')
plt.xlabel('Ad Budget (Kshs)')
plt.ylabel('Monthly Sales (Kshs)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Exercise 4: Box plot to assess sales distribution across branches

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Branch', y='Monthly Sales (Kshs)', data=df, palette='pastel')
plt.title('Sales Distribution Across Branches')
plt.xlabel('Branch')
plt.ylabel('Monthly Sales (Kshs)')
plt.grid(True, axis='y')
plt.show()
# Out:
# /tmp/ipykernel_27034/1009528552.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Branch', y='Monthly Sales (Kshs)', data=df, palette='pastel')
